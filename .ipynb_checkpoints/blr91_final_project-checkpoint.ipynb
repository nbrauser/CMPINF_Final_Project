# %% [markdown]
# The goal of this project is to identify the best neighborhood in Pittsburgh using public safety as the main evaluation metric. To do this, I analyzed citywide police data and focused specifically on non-traffic violations, since these incidents provide a clearer picture of community safety. Each type of violation was assigned a weighted value based on its severity, allowing neighborhoods to be compared not just by the number of incidents, but by the overall impact of those incidents. By combining these weights with the frequency of violations in each neighborhood, I created a scoring system that ranks neighborhoods from safest to least safe. This approach provides a data-driven method for evaluating quality of life and determining which neighborhood can be considered “the best” in terms of public safety.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the uploaded dataset
df = pd.read_csv("Police_data.csv")

# Normalize neighborhood text (removes casing / extra spaces issues)
df['NEIGHBORHOOD'] = df['NEIGHBORHOOD'].astype(str).str.upper().str.strip()

# Remove non-Pittsburgh locations
remove_terms = ["OUTSIDE", "UNKNOWN", "UNIDENTIFIED", "UNABLE TO RETRIEVE ADDRESS"]
for term in remove_terms:
    df = df[~df['NEIGHBORHOOD'].str.contains(term, case=False, na=False)]

# Count occurrences per neighborhood
neighborhood_counts = df['NEIGHBORHOOD'].value_counts()

# Create bar chart
plt.figure(figsize=(14, 7))
plt.bar(neighborhood_counts.index, neighborhood_counts.values)
plt.xticks(rotation=90)
plt.xlabel("Neighborhood")
plt.ylabel("Number of Violations")
plt.title("Non-Traffic Violations per Pittsburgh Neighborhood")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the uploaded dataset
df = pd.read_csv("Police_data.csv")

# Clean text to ensure matching
df['NEIGHBORHOOD'] = df['NEIGHBORHOOD'].astype(str).str.upper().str.strip()

# Remove invalid/non-Pittsburgh neighborhood entries
remove_terms = ["OUTSIDE", "UNKNOWN", "UNIDENTIFIED", "UNABLE TO RETRIEVE ADDRESS"]
for term in remove_terms:
    df = df[~df['NEIGHBORHOOD'].str.contains(term, case=False, na=False)]

# Count occurrences per neighborhood
neighborhood_counts = df['NEIGHBORHOOD'].value_counts()

# Select the bottom 25 (safest)
bottom25 = neighborhood_counts.sort_values(ascending=True).head(25)

# Create bar chart
plt.figure(figsize=(14, 7))
plt.bar(bottom25.index, bottom25.values)
plt.xticks(rotation=90)
plt.xlabel("Neighborhood")
plt.ylabel("Number of Violations")
plt.title("Bottom 25 Pittsburgh Neighborhoods by Non-Traffic Violations (Unweighted)")
plt.tight_layout()
plt.show()

# %% [raw]
# I weighted each offese by severity. Made the new graph based on these weighted values.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("Police_data.csv")

df['NEIGHBORHOOD'] = df['NEIGHBORHOOD'].astype(str).str.upper().str.strip()

# Remove invalid/non-Pittsburgh neighborhood entries
remove_terms = ["OUTSIDE", "UNKNOWN", "UNIDENTIFIED", "UNABLE TO RETRIEVE ADDRESS"]
for term in remove_terms:
    df = df[~df['NEIGHBORHOOD'].str.contains(term, case=False, na=False)]

# Weighting model
def get_weight(offense):
    offense = str(offense).upper()
    if "HOMICIDE" in offense:
        return 5
    elif "AGGRAVATED ASSAULT" in offense:
        return 4
    elif "ROBBERY" in offense:
        return 4
    elif "BURGLARY" in offense:
        return 3
    elif "THEFT" in offense:
        return 2
    elif "VANDALISM" in offense:
        return 2
    elif "DISORDERLY" in offense:
        return 1
    elif "LIQUOR" in offense:
        return 1
    else:
        return 0.5

df["WEIGHT"] = df["OFFENSES"].apply(get_weight)

# Recalculate weighted + incident counts
neigh_scores = df.groupby("NEIGHBORHOOD").agg(
    Weighted_Score=("WEIGHT", "sum"),
    Total_Incidents=("NEIGHBORHOOD", "count")
)

# Bottom 15 safest neighborhoods
bottom15 = neigh_scores.sort_values("Weighted_Score", ascending=True).head(25)
# print(bottom15)

# Plot
plt.figure(figsize=(14, 7))
plt.bar(bottom15.index, bottom15["Weighted_Score"])
plt.xticks(rotation=90)
plt.ylabel("Weighted Crime Severity Score")
plt.title("Bottom 15 Safest Pittsburgh Neighborhoods (Weighted)")
plt.tight_layout()
plt.show()

# %% [markdown]
# To complement the public safety analysis, this project also incorporates neighborhood park data to provide a broader view of community livability. Park factors such as quantity, size, and amenities were examined to understand the accessibility and quality of green spaces in each neighborhood. Combining this information with safety scores creates a more complete evaluation of which neighborhoods offer the strongest overall environment for residents.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the uploaded dataset
df = pd.read_csv("parks.csv")

# Normalize neighborhood text (removes casing / extra spaces issues)
df['neighborhood'] = df['neighborhood'].astype(str).str.upper().str.strip()
df['type'] = df['type'].astype(str).str.upper().str.strip()

# Filter for only parks
park_df = df[df['type'] == "PARK"]

# Count occurrences per neighborhood
neighborhood_counts = park_df['neighborhood'].value_counts()
# Create bar chart
plt.figure(figsize=(14, 7))
plt.bar(neighborhood_counts.index, neighborhood_counts.values)
plt.xticks(rotation=90)
plt.xlabel("Neighborhood")
plt.ylabel("Number of parks")
plt.title("Parks per Pittsburgh Neighborhood")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the uploaded dataset
df = pd.read_csv("parks.csv")

# Clean text to ensure matching
df['neighborhood'] = df['neighborhood'].astype(str).str.upper().str.strip()
df['type'] = df['type'].astype(str).str.upper().str.strip()

# Filter for only actual parks
park_df = df[df['type'] == "PARK"]

# Count occurrences per neighborhood
neighborhood_counts = park_df['neighborhood'].value_counts()


# Select the top 25 neighborhoods with the most parks
top25 = neighborhood_counts.sort_values(ascending=False).head(25)

# Create bar chart
plt.figure(figsize=(14, 7))
plt.bar(top25.index, top25.values)
plt.xticks(rotation=90)
plt.xlabel("Neighborhood")
plt.ylabel("Number of Parks")
plt.title("Parks per Pittsburgh Neighborhood")
plt.tight_layout()
plt.show()

# %% [markdown]
# The data-driven “best neighborhood” in Pittsburgh is Chartiers City, mainly because it has lower crime rates. My personal favorite, however, is Beechview, which I enjoy for its atmosphere and local charm, even though its crime rates are higher. I also live here which is a big factor in why its my favorite.

# %%
neighborhood_counts.to_csv('changedParks.csv', index=True) 
neigh_scores.to_csv('changedPolice.csv', index=True)
