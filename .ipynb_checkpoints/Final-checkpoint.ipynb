# %% [markdown]
# Best Neighborhood for Income to Rent Ration:
# 1             Point Breeze
# 2            Allegheny West
# 3            East Carnegie
# 4            Regent Square
# 5          Stanton Heights
# 6               Manchester
# 7                  Bon Air
# 8          Crafton Heights
# 9              Perry North
# 10                 Fineview
# 11    Spring Hill-City View
# 12               Mt. Oliver
# 13         Brighton Heights
# 14              Summer Hill
# 15            Lincoln Place

# %% [markdown]
# Best Neighborhood for Least amount of crime:
# 1 CHARTIERS CITY
# 2 MT. OLIVER NEIGHBORHOOD
# 3 MT. OLIVER BORO
# 4 RIDGEMONT
# 5 ST. CLAIR
# 6 SUMMER HILL
# 7 NEW HOMESTEAD
# 8 ARLINGTON HEIGHTS
# 9 SWISSHELM PARK
# 10 REGENT SQUARE
# 11 SPRING GARDEN
# 12 OAKWOOD
# 13 HAYS
# 14 FAIRYWOOD

# %%
leastCrime = ['CHARTIERS CITY',
              'MT.OLIVER',
              'MT.OLIVER BORO',
              'RIDGEMONT',
              'ST.CLAIR',
              'SUMMER HILL',
              'NEW HOMESTEAD',
              'ARLINGTON HEIGHTS',
              'SWISSHELM PARK',
              'REGENT SQUARE',
              'SPRING GARDEN',
              'OAKWOOD',
              'HAYS',
              'FAIRYWOOD']
bestIncomeRatio = ['Point Breeze',
                   'Allegheny West',
                   'East Carnegie',
                   'Regent Square',
                   'Stanton Heights',
                   'Manchester',
                   'Bon Air',
                   'Crafton Heights',
                   'Perry North',
                   'Fineview',
                   'Spring Hill-City View',
                   'Mt.Oliver',
                   'Brighton Heights',
                   'Summer Hill',
                   'Lincoln Place']
both = []
for i in range(len(bestIncomeRatio)):
    bestIncomeRatio[i] = bestIncomeRatio[i].lower()
for i in range(len(leastCrime)):
    leastCrime[i] = leastCrime[i].lower()
for neighborhood in leastCrime:
    if neighborhood in bestIncomeRatio:
        both.append(neighborhood)
print(both)
# Out:
# ['mt.oliver', 'summer hill', 'regent square']

# %% [markdown]
# The neighborhoods that showed up in both of the top 15 each data set was mt.oliver, summer hill, regent square. These were the three neighborhoods that we wanted to decide from for our best neighborhood. To decide from these three we picked mt.oliver Because it was the only neighborhood out of the three that was in the top three of either category.
